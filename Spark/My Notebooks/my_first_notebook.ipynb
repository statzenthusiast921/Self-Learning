# %%
import pyspark

# %%
#This line is just for DataBricks users
df = sqlContext.sql("SELECT * FROM mydata_3_csv")

# %%
df.show()
# Out:
# +-----+-----+
# | name|sales|
# +-----+-----+
# | John|  100|
# |Cindy|   86|
# | Carl|  230|
# +-----+-----+

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Basics').getOrCreate()

# %%
df = spark.read.json('/FileStore/tables/people.json')

# %%
df
# Out:
# Out[33]: DataFrame[age: bigint, name: string]

# %%
df.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
df.printSchema()
# Out:
# root
#  |-- age: long (nullable = true)
#  |-- name: string (nullable = true)

# %%
df.columns
# Out:
# Out[36]: ['age', 'name']

# %%
df.describe().show()
# Out:
# +-------+------------------+-------+
# |summary|               age|   name|
# +-------+------------------+-------+
# |  count|                 2|      3|
# |   mean|              24.5|   null|
# | stddev|7.7781745930520225|   null|
# |    min|                19|   Andy|
# |    max|                30|Michael|
# +-------+------------------+-------+

# %%
from pyspark.sql.types import StructField, StringType, IntegerType, StructType

# %%
data_schema = [
    StructField('age',IntegerType(),True),
    StructField('name',StringType(),True)
]

# %%
final_struct = StructType(fields = data_schema)

# %%
df = spark.read.json('/FileStore/tables/people.json',schema = final_struct)

# %%
df.printSchema()
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- name: string (nullable = true)

# %%
df['age']
# Out:
# Out[45]: Column<'age'>

# %%
type(df['age'])
# Out:
# Out[46]: pyspark.sql.column.Column

# %%
df.select('age').show()
print(df.select('age'))
# Out:
# +----+
# | age|
# +----+
# |null|
# |  30|
# |  19|
# +----+
#
# DataFrame[age: int]

# %%
df.head(2)[0]
# Out:
# Out[51]: Row(age=None, name='Michael')

# %%
df.select(['age','name']).show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
df.withColumn('newAge',df['age']).show()
# Out:
# +----+-------+------+
# | age|   name|newAge|
# +----+-------+------+
# |null|Michael|  null|
# |  30|   Andy|    30|
# |  19| Justin|    19|
# +----+-------+------+

# %%
df.withColumn('DoubleAge',df['age']*2).show()
# Out:
# +----+-------+---------+
# | age|   name|DoubleAge|
# +----+-------+---------+
# |null|Michael|     null|
# |  30|   Andy|       60|
# |  19| Justin|       38|
# +----+-------+---------+

# %%
df.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
df.withColumnRenamed('age','my_new_age').show()
# Out:
# +----------+-------+
# |my_new_age|   name|
# +----------+-------+
# |      null|Michael|
# |        30|   Andy|
# |        19| Justin|
# +----------+-------+

# %%
df.createOrReplaceTempView('people')

# %%
results = spark.sql("SELECT * FROM people")

# %%
results.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
new_results = spark.sql("SELECT * FROM people WHERE age = 30")
new_results.show()
# Out:
# +---+----+
# |age|name|
# +---+----+
# | 30|Andy|
# +---+----+
