# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('ops').getOrCreate()

# %%
df = spark.read.table('appl_stock_csv')

# %%
df.printSchema()
# Out:
# root
#  |-- Date: timestamp (nullable = true)
#  |-- Open: float (nullable = true)
#  |-- High: float (nullable = true)
#  |-- Low: float (nullable = true)
#  |-- Close: string (nullable = true)
#  |-- Volume: integer (nullable = true)
#  |-- Adj Close: float (nullable = true)

# %%
df.show(4)
# Out:
# +-------------------+---------+------+------+----------+---------+---------+
# |               Date|     Open|  High|   Low|     Close|   Volume|Adj Close|
# +-------------------+---------+------+------+----------+---------+---------+
# |2010-01-04 00:00:00|   213.43| 214.5|212.38|214.009998|123432400| 27.72704|
# |2010-01-05 00:00:00|214.59999|215.59|213.25|214.379993|150476200|27.774977|
# |2010-01-06 00:00:00|214.37999|215.23|210.75|210.969995|138040000|27.333178|
# |2010-01-07 00:00:00|   211.75| 212.0|209.05|    210.58|119282800| 27.28265|
# +-------------------+---------+------+------+----------+---------+---------+
# only showing top 4 rows

# %%
#df.filter("Close < 500").select(["Open","Close"]).show()
# Out:
# +---------+------------------+
# |     Open|             Close|
# +---------+------------------+
# |   213.43|        214.009998|
# |214.59999|        214.379993|
# |214.37999|        210.969995|
# |   211.75|            210.58|
# |210.29999|211.98000499999998|
# |    212.8|210.11000299999998|
# |   209.19|        207.720001|
# |207.87001|        210.650002|
# |   210.11|            209.43|
# |   210.93|            205.93|
# |   208.33|        215.039995|
# |   214.91|            211.73|
# |212.07999|        208.069996|
# |   206.78|            197.75|
# |   202.51|        203.070002|
# |   205.95|        205.940001|
# |206.84999|        207.880005|
# |204.93001|        199.289995|
# |   201.08|        192.060003|
# |   192.37|        194.729998|
# +---------+------------------+
# only showing top 20 rows

# %%
df.filter(df["Close"]<500).select("Volume").show()
# Out:
# +---------+
# |   Volume|
# +---------+
# |123432400|
# |150476200|
# |138040000|
# |119282800|
# |111902700|
# |115557400|
# |148614900|
# |151473000|
# |108223500|
# |148516900|
# |182501900|
# |153038200|
# |152038600|
# |220441900|
# |266424900|
# |466777500|
# |430642100|
# |293375600|
# |311488100|
# |187469100|
# +---------+
# only showing top 20 rows

# %%
df.filter((df['Close']<200) & ~(df['Open']>200)).show()
# Out:
# +-------------------+------+---------+---------+------------------+---------+---------+
# |               Date|  Open|     High|      Low|             Close|   Volume|Adj Close|
# +-------------------+------+---------+---------+------------------+---------+---------+
# |2010-02-01 00:00:00|192.37|    196.0|    191.3|        194.729998|187469100|25.229132|
# |2010-02-02 00:00:00|195.91|196.31999|193.37999|        195.859997|174585600|25.375532|
# |2010-02-03 00:00:00|195.17|    200.2|   194.42|        199.229994|153832000| 25.81215|
# |2010-02-04 00:00:00|196.73|   198.37|   191.57|        192.050003|189413000|24.881912|
# |2010-02-05 00:00:00|192.63|    196.0|   190.85|        195.460001|212576700| 25.32371|
# |2010-02-08 00:00:00|195.69|   197.88|    194.0|194.11999699999998|119567700|  25.1501|
# |2010-02-09 00:00:00|196.42|    197.5|   194.75|196.19000400000002|158221700| 25.41829|
# |2010-02-10 00:00:00|195.89|    196.6|   194.26|195.12000700000002| 92590400| 25.27966|
# |2010-02-11 00:00:00|194.88|   199.75|   194.06|        198.669994|137586400|25.739595|
# |2010-02-23 00:00:00| 200.0|   201.33|195.70999|        197.059998|143773700|25.531006|
# |2014-06-09 00:00:00|  92.7|    93.88|    91.75|         93.699997| 75415000| 88.90633|
# |2014-06-10 00:00:00| 94.73|    95.05|    93.57|             94.25| 62777000| 89.42819|
# |2014-06-11 00:00:00| 94.13|    94.76|    93.47|         93.860001| 45681000| 89.05814|
# |2014-06-12 00:00:00| 94.04|    94.12|     91.9|         92.290001| 54749000| 87.56847|
# |2014-06-13 00:00:00|  92.2|    92.44|    90.88|         91.279999| 54525000| 86.61013|
# |2014-06-16 00:00:00| 91.51|    92.75|    91.45|         92.199997| 35561000| 87.48306|
# |2014-06-17 00:00:00| 92.31|     92.7|     91.8| 92.08000200000001| 29726000| 87.36921|
# |2014-06-18 00:00:00| 92.27|    92.29|    91.35|             92.18| 33514000| 87.46409|
# |2014-06-19 00:00:00| 92.29|     92.3|    91.34|         91.860001| 35528000| 87.16046|
# |2014-06-20 00:00:00| 91.85|    92.55|     90.9|         90.910004|100898000| 86.25906|
# +-------------------+------+---------+---------+------------------+---------+---------+
# only showing top 20 rows

# %%
df.filter(df['Low']<89.5).show()
# Out:
# +-------------------+-----+-----+-----+---------+--------+---------+
# |               Date| Open| High|  Low|    Close|  Volume|Adj Close|
# +-------------------+-----+-----+-----+---------+--------+---------+
# |2016-05-12 00:00:00|92.72|92.78|89.47|90.339996|76314700| 89.00837|
# +-------------------+-----+-----+-----+---------+--------+---------+

# %%
result = df.filter(df['Low']<89.5).collect()
result
# Out:
# Out[55]: [Row(Date=datetime.datetime(2016, 5, 12, 0, 0), Open=92.72000122070312, High=92.77999877929688, Low=89.47000122070312, Close='90.339996', Volume=76314700, Adj Close=89.00836944580078)]

# %%
row = result[0]

# %%
row.asDict()['Volume']
# Out:
# Out[58]: 76314700
