# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd
import base64

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/wheels.csv')

# %%
df.head()
# Out:
#    wheels   color               image
# 0       1     red     redunicycle.jpg
# 1       1    blue    blueunicycle.jpg
# 2       1  yellow  yellowunicycle.jpg
# 3       2     red      redbicycle.jpg
# 4       2    blue  bluemotorcycle.jpg

# %%
app = dash.Dash()

def encode_image(image_file):
    encoded = base64.b64encode(open(image_file,'rb'),read())
    return 'data:image/png;base64,{}'.format(encoded.decode())


app.layout = html.Div([
    dcc.RadioItems(id='wheels',
                  options=[{'label':i,
                            'value':i}
                          for i in df['wheels'].unique()],
                   value=1
                  ),
    html.Div(id='wheels-output'),
    html.Hr(),
    dcc.RadioItems(id='colors',
                   options=[{'label':i,
                            'value':i}
                          for i in df['color'].unique()],
                   value='blue'),
    html.Div(id='colors-output'),
    html.Img(id='display-image',src='children',height=300)
],style={'fontFamily':'helvetica','fontSize':18})


#-------------------Configure reactivity-------------------#
@app.callback(Output("wheels-output","children"),
              Input("wheels","value"))
def callback_a(wheels_value):
    return "You chose {}".format(wheels_value)


@app.callback(Output("colors-output","children"),
              Input("colors","value"))
def callback_a(colors_value):
    return "You chose {}".format(colors_value)


@app.callback(Output('display-image','src'),
              Input('wheels','value'),
              Input('colors','value'))

def callback_image(wheel,color):
    path = '/Use/Desktop/Udemy Courses/Plotly Dash/Lesson 9 - Interactive Components/images/'
    return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])











app.run_server(host='0.0.0.0',port='8050')
# Out:
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [25/Mar/2021 09:52:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2021 09:52:43] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2021 09:52:43] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2021 09:52:43] "GET /children HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2021 09:52:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2021 09:52:43] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-5-8d5f8860d0b2>", line 46, in callback_image
#     return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])
#   File "<ipython-input-5-8d5f8860d0b2>", line 4, in encode_image
#     encoded = base64.b64encode(open(image_file,'rb'),read())
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/Pierian-Data/Plotly-Dashboards-with-Dash/tree/master/Data/Imagesblueunicycle.jpg'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-5-8d5f8860d0b2>", line 46, in callback_image
#     return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])
#   File "<ipython-input-5-8d5f8860d0b2>", line 4, in encode_image
#     encoded = base64.b64encode(open(image_file,'rb'),read())
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/Pierian-Data/Plotly-Dashboards-with-Dash/tree/master/Data/Imagesblueunicycle.jpg'
# 127.0.0.1 - - [25/Mar/2021 09:52:43] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [25/Mar/2021 09:52:45] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-5-8d5f8860d0b2>", line 46, in callback_image
#     return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])
#   File "<ipython-input-5-8d5f8860d0b2>", line 4, in encode_image
#     encoded = base64.b64encode(open(image_file,'rb'),read())
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/Pierian-Data/Plotly-Dashboards-with-Dash/tree/master/Data/Imagesbluemotorcycle.jpg'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-5-8d5f8860d0b2>", line 46, in callback_image
#     return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])
#   File "<ipython-input-5-8d5f8860d0b2>", line 4, in encode_image
#     encoded = base64.b64encode(open(image_file,'rb'),read())
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/Pierian-Data/Plotly-Dashboards-with-Dash/tree/master/Data/Imagesbluemotorcycle.jpg'
# 127.0.0.1 - - [25/Mar/2021 09:52:45] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [25/Mar/2021 09:52:46] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-5-8d5f8860d0b2>", line 46, in callback_image
#     return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])
#   File "<ipython-input-5-8d5f8860d0b2>", line 4, in encode_image
#     encoded = base64.b64encode(open(image_file,'rb'),read())
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/Pierian-Data/Plotly-Dashboards-with-Dash/tree/master/Data/Imagesbluetricycle.jpg'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-5-8d5f8860d0b2>", line 46, in callback_image
#     return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])
#   File "<ipython-input-5-8d5f8860d0b2>", line 4, in encode_image
#     encoded = base64.b64encode(open(image_file,'rb'),read())
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/Pierian-Data/Plotly-Dashboards-with-Dash/tree/master/Data/Imagesbluetricycle.jpg'
# 127.0.0.1 - - [25/Mar/2021 09:52:46] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [25/Mar/2021 09:52:47] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-5-8d5f8860d0b2>", line 46, in callback_image
#     return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])
#   File "<ipython-input-5-8d5f8860d0b2>", line 4, in encode_image
#     encoded = base64.b64encode(open(image_file,'rb'),read())
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/Pierian-Data/Plotly-Dashboards-with-Dash/tree/master/Data/Imagesredtricycle.jpg'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-5-8d5f8860d0b2>", line 46, in callback_image
#     return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])
#   File "<ipython-input-5-8d5f8860d0b2>", line 4, in encode_image
#     encoded = base64.b64encode(open(image_file,'rb'),read())
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/Pierian-Data/Plotly-Dashboards-with-Dash/tree/master/Data/Imagesredtricycle.jpg'
# 127.0.0.1 - - [25/Mar/2021 09:52:47] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [25/Mar/2021 09:52:48] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-5-8d5f8860d0b2>", line 46, in callback_image
#     return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])
#   File "<ipython-input-5-8d5f8860d0b2>", line 4, in encode_image
#     encoded = base64.b64encode(open(image_file,'rb'),read())
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/Pierian-Data/Plotly-Dashboards-with-Dash/tree/master/Data/Imagesyellowrickshaw.jpg'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-5-8d5f8860d0b2>", line 46, in callback_image
#     return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])
#   File "<ipython-input-5-8d5f8860d0b2>", line 4, in encode_image
#     encoded = base64.b64encode(open(image_file,'rb'),read())
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/Pierian-Data/Plotly-Dashboards-with-Dash/tree/master/Data/Imagesyellowrickshaw.jpg'
# 127.0.0.1 - - [25/Mar/2021 09:52:48] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [25/Mar/2021 09:55:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2021 09:56:00] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2021 09:56:00] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2021 09:56:00] "GET /children HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2021 09:56:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2021 09:56:00] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-5-8d5f8860d0b2>", line 46, in callback_image
#     return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])
#   File "<ipython-input-5-8d5f8860d0b2>", line 4, in encode_image
#     encoded = base64.b64encode(open(image_file,'rb'),read())
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/Pierian-Data/Plotly-Dashboards-with-Dash/tree/master/Data/Imagesblueunicycle.jpg'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-5-8d5f8860d0b2>", line 46, in callback_image
#     return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])
#   File "<ipython-input-5-8d5f8860d0b2>", line 4, in encode_image
#     encoded = base64.b64encode(open(image_file,'rb'),read())
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/Pierian-Data/Plotly-Dashboards-with-Dash/tree/master/Data/Imagesblueunicycle.jpg'
# 127.0.0.1 - - [25/Mar/2021 09:56:00] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [25/Mar/2021 14:54:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2021 14:54:39] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2021 14:54:39] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2021 14:54:39] "GET /children HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2021 14:54:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Mar/2021 14:54:39] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-5-8d5f8860d0b2>", line 46, in callback_image
#     return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])
#   File "<ipython-input-5-8d5f8860d0b2>", line 4, in encode_image
#     encoded = base64.b64encode(open(image_file,'rb'),read())
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/Pierian-Data/Plotly-Dashboards-with-Dash/tree/master/Data/Imagesblueunicycle.jpg'
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-5-8d5f8860d0b2>", line 46, in callback_image
#     return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])
#   File "<ipython-input-5-8d5f8860d0b2>", line 4, in encode_image
#     encoded = base64.b64encode(open(image_file,'rb'),read())
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/Pierian-Data/Plotly-Dashboards-with-Dash/tree/master/Data/Imagesblueunicycle.jpg'
# 127.0.0.1 - - [25/Mar/2021 14:54:39] "POST /_dash-update-component HTTP/1.1" 500 -
