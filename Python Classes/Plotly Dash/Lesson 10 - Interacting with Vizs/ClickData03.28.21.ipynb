# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.graph_objs as go
import pandas as pd
import json
import base64

# %%
app = dash.Dash()


def encode_image(image_file):
    encoded = base64.b64encode(open(image_file,'rb'),read())
    return 'data:image/png;base64,{}'.format(encoded.decode())


df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/wheels.csv')
app.layout = html.Div([
    html.Div(dcc.Graph(id='wheels-plot',
                       figure={'data':[go.Scatter(
                                           x=df['color'],
                                           y=df['wheels'],
                                           dy=1,
                                           mode='markers',
                                           marker={'size':15}
                       )],
                              'layout':go.Layout(title='Test',
                                                hovermode='closest')}
                      ),style={'width':'30%','float':'left'}),
    html.Div(html.Img(id='hover-data',src='children',height=300),
            style={'paddingTop':'35%'})
])

#THE ONLY THING THAT CHANGED WAS SWAPPING OUT hoverData with clickData
@app.callback(Output('hover-data','src'),
              Input('wheels-plot','clickData'))
def callback_image(hoverData):
    wheel = hoverData['points'][0]['y']
    color = hoverData['points'][0]['x']
    path = "/Users/jonzimmerman/Desktop/Udemy Courses/Plotly Dash/Lesson 9 - Interactive Components/images/"
    return encode_image(path+df[(df['wheels']==wheel) & (df['color']==color)]['image'].values[0])


# if __name__ =="__main__":
#     app.run_server()
app.run_server(host='0.0.0.0',port='8054')
# Out:
# Dash is running on http://0.0.0.0:8054/
#
# Dash is running on http://0.0.0.0:8054/
#
# Dash is running on http://0.0.0.0:8054/
#
# Dash is running on http://0.0.0.0:8054/
#
# Dash is running on http://0.0.0.0:8054/
#
# Dash is running on http://0.0.0.0:8054/
#
# Dash is running on http://0.0.0.0:8054/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:8054/ (Press CTRL+C to quit)
# 127.0.0.1 - - [28/Mar/2021 17:18:40] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2021 17:18:40] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2021 17:18:40] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2021 17:18:40] "GET /_favicon.ico?v=1.19.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2021 17:18:40] "GET /children HTTP/1.1" 200 -
# ...
