# %%
import pandas
df7=pandas.read_json("http://pythonhow.com/supermarkets.json")

# %%
#Data comes with a header
df7
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
#Use the argument header=None if no header --> will instead print index

# %%
df7.columns = ("ID","Address","City","ZIP","Country","Shop","NumEmps")

# %%
df7
# Out:
#    ID          Address           City               ZIP Country         Shop  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    NumEmps
# 0        8
# 1       15
# 2       25
# 3       10
# 4       12
# 5       20

# %%
df7=df7.set_index("Address")

# %%
df7
# Out:
#                           City               ZIP Country         Shop  NumEmps
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira        8
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop       15
# 332 Hill St      San Francisco  California 94114     USA  Super River       25
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop       10
# 1056 Sanchez St  San Francisco        California     USA      Sanchez       12
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley       20

# %%
#First Row becomes the header
df8=pandas.read_csv("data.txt")

# %%
df8
# Out:
#    1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 0  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 1  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 2  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 3  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 4  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df8=pandas.read_csv("data.txt",header=None)

# %%
df8
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df8.columns = ("ID","Address","City","ZIP","Country","Name","NumEmps")

# %%
df8
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    NumEmps
# 0        8
# 1       15
# 2       25
# 3       10
# 4       12
# 5       20

# %%
df7=pandas.read_json("http://pythonhow.com/supermarkets.json")

# %%
df7=df7.set_index("Address")

# %%
df7.loc["735 Dolores St":"332 Hill St","Country":"ID"]
# Out:
# Empty DataFrame
# Columns: []
# Index: [735 Dolores St, 332 Hill St]

# %%
print(df7.loc["332 Hill St","Country"])
print(df7.loc["332 Hill St","Name"])
print(df7.loc["551 Alvarado St","City"])
# Out:
# USA
# Super River
# San Francisco

# %%
print(list(df7.loc[:,"Country"]))
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7.iloc[1:3,1:3]
# Out:
#                          City             State
# Address
# 735 Dolores St  San Francisco          CA 94119
# 332 Hill St     San Francisco  California 94114

# %%
df7.iloc[1:4,1:4]
# Out:
#                          City             State Country
# Address
# 735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St     San Francisco  California 94114     USA
# 3995 23rd St    San Francisco          CA 94114     USA

# %%
df7.iloc[3,1:3]
# Out:
# City     San Francisco
# State         CA 94114
# Name: 3995 23rd St, dtype: object

# %%
#Deleting columns or rows from data frames

# %%
df7.drop("City",1)
# Out:
#                  ID             State Country         Name  Employees
# Address
# 3666 21st St      1          CA 94114     USA      Madeira          8
# 735 Dolores St    2          CA 94119     USA  Bready Shop         15
# 332 Hill St       3  California 94114     USA  Super River         25
# 3995 23rd St      4          CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5        California     USA      Sanchez         12
# 551 Alvarado St   6          CA 94114     USA   Richvalley         20

# %%
df7.drop?

# %%
df7=df7.drop("332 Hill St",0)

# %%
df7
# Out:
#                  ID           City       State Country         Name  Employees
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley         20

# %%
df7.drop(df7.index[0:3],0)
# Out:
#                  ID           City       State Country        Name  Employees
# Address
# 1056 Sanchez St   5  San Francisco  California     USA     Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA  Richvalley         20

# %%
df7.index
# Out:
# Index(['3666 21st St', '735 Dolores St', '3995 23rd St', '1056 Sanchez St',
#        '551 Alvarado St'],
#       dtype='object', name='Address')

# %%
df7.columns
# Out:
# Index(['ID', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
#Updating and Adding New Columns/Rows

# %%
df7
# Out:
#                  ID           City       State Country         Name  Employees
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley         20

# %%
df7["Continent"]=df7.shape[0]*["North America"]

# %%
df7
# Out:
#                  ID           City       State Country         Name  \
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley
#
#                  Employees      Continent
# Address
# 3666 21st St             8  North America
# 735 Dolores St          15  North America
# 3995 23rd St            10  North America
# 1056 Sanchez St         12  North America
# 551 Alvarado St         20  North America

# %%
print(df7.shape)
print(df7.shape[0])
print(df7.shape[0]*["North America"])
# Out:
# (5, 7)
# 5
# ['North America', 'North America', 'North America', 'North America', 'North America']

# %%
df7["Continent"]=df7["Country"]+", "+"North America"

# %%
df7
# Out:
#                  ID           City       State Country         Name  \
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley
#
#                  Employees           Continent
# Address
# 3666 21st St             8  USA, North America
# 735 Dolores St          15  USA, North America
# 3995 23rd St            10  USA, North America
# 1056 Sanchez St         12  USA, North America
# 551 Alvarado St         20  USA, North America

# %%
df7_t = df7.T

# %%
df7_t
# Out:
# Address          3666 21st St      735 Dolores St        3995 23rd St  \
# ID                          1                   2                   4
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119            CA 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop          Ben's Shop
# Employees                   8                  15                  10
# Continent  USA, North America  USA, North America  USA, North America
#
# Address       1056 Sanchez St     551 Alvarado St
# ID                          5                   6
# City            San Francisco       San Francisco
# State              California            CA 94114
# Country                   USA                 USA
# Name                  Sanchez          Richvalley
# Employees                  12                  20
# Continent  USA, North America  USA, North America

# %%
df7_t["My Address"] = ["My City","My Country",10,7,"My Shop","My State","My Company"]

# %%
df7_t
# Out:
# Address          3666 21st St      735 Dolores St        3995 23rd St  \
# ID                          1                   2                   4
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119            CA 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop          Ben's Shop
# Employees                   8                  15                  10
# Continent  USA, North America  USA, North America  USA, North America
#
# Address       1056 Sanchez St     551 Alvarado St  My Address
# ID                          5                   6     My City
# City            San Francisco       San Francisco  My Country
# State              California            CA 94114          10
# Country                   USA                 USA           7
# Name                  Sanchez          Richvalley     My Shop
# ...

# %%
df7=df7_t.T

# %%
df7
# Out:
#                       ID           City       State Country         Name  \
# Address
# 3666 21st St           1  San Francisco    CA 94114     USA      Madeira
# 735 Dolores St         2  San Francisco    CA 94119     USA  Bready Shop
# 3995 23rd St           4  San Francisco    CA 94114     USA   Ben's Shop
# 1056 Sanchez St        5  San Francisco  California     USA      Sanchez
# 551 Alvarado St        6  San Francisco    CA 94114     USA   Richvalley
# My Address       My City     My Country          10       7      My Shop
#
#                 Employees           Continent
# Address
# 3666 21st St            8  USA, North America
# 735 Dolores St         15  USA, North America
# 3995 23rd St           10  USA, North America
# 1056 Sanchez St        12  USA, North America
# 551 Alvarado St        20  USA, North America
# My Address       My State          My Company

# %%
df7
# Out:
#                       ID           City       State Country         Name  \
# Address
# 3666 21st St           1  San Francisco    CA 94114     USA      Madeira
# 735 Dolores St         2  San Francisco    CA 94119     USA  Bready Shop
# 3995 23rd St           4  San Francisco    CA 94114     USA   Ben's Shop
# 1056 Sanchez St        5  San Francisco  California     USA      Sanchez
# 551 Alvarado St        6  San Francisco    CA 94114     USA   Richvalley
# My Address       My City     My Country          10       7      My Shop
#
#                 Employees           Continent
# Address
# 3666 21st St            8  USA, North America
# 735 Dolores St         15  USA, North America
# 3995 23rd St           10  USA, North America
# 1056 Sanchez St        12  USA, North America
# 551 Alvarado St        20  USA, North America
# My Address       My State          My Company

# %%
dm=pandas.merge(left=df7,right=df7,on="ID")

# %%
dm
# Out:
#         ID         City_x     State_x Country_x       Name_x Employees_x  \
# 0        1  San Francisco    CA 94114       USA      Madeira           8
# 1        2  San Francisco    CA 94119       USA  Bready Shop          15
# 2        4  San Francisco    CA 94114       USA   Ben's Shop          10
# 3        5  San Francisco  California       USA      Sanchez          12
# 4        6  San Francisco    CA 94114       USA   Richvalley          20
# 5  My City     My Country          10         7      My Shop    My State
#
#           Continent_x         City_y     State_y Country_y       Name_y  \
# 0  USA, North America  San Francisco    CA 94114       USA      Madeira
# 1  USA, North America  San Francisco    CA 94119       USA  Bready Shop
# 2  USA, North America  San Francisco    CA 94114       USA   Ben's Shop
# 3  USA, North America  San Francisco  California       USA      Sanchez
# 4  USA, North America  San Francisco    CA 94114       USA   Richvalley
# ...

# %%
type(df7)
# Out:
# pandas.core.frame.DataFrame

# %%
import geopy

# %%
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_info__',
#  'adapters',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'get_version',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
n=nom.geocode("3995 23rd St, San Francisco, CA 94114")

# %%
n.latitude
# Out:
# 37.75292200397371

# %%
n.longitude
# Out:
# -122.43169700840102

# %%
type(n)
# Out:
# geopy.location.Location

# %%
df=pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"] = df["Address"]+", "+df["City"]+", "+df["State"]+", "+df["Country"]

# %%
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)

# %%
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
df.Coordinates[0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.756648011392286, -122.42937496976432, 0.0))

# %%
df.Coordinates[0].latitude
# Out:
# 37.756648011392286

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x:x.latitude if x!= None else None)

# %%
df["Longitude"]=df["Coordinates"].apply(lambda x:x.longitude if x!= None else None)

# %%
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
