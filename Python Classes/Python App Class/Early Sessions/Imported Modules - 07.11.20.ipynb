# %%
#Builtin Modules
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
dir(__builtin__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
#Want to print this out every 10 seconds, but this prints out every second
while True:
    with open("folder/vegetables.txt") as file:
        print(file.read())
# Out:
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# ...

# %%
import sys
sys.builtin_module_names
# Out:
# ('_abc',
#  '_ast',
#  '_codecs',
#  '_collections',
#  '_functools',
#  '_imp',
#  '_io',
#  '_locale',
#  '_operator',
#  '_signal',
#  '_sre',
#  '_stat',
#  '_string',
#  '_symtable',
#  '_thread',
#  '_tracemalloc',
#  '_warnings',
#  '_weakref',
#  'atexit',
#  'builtins',
#  'errno',
#  'faulthandler',
#  'gc',
#  'itertools',
#  'marshal',
#  'posix',
#  'pwd',
#  'sys',
#  'time',
#  'xxsubtype',
#  'zipimport')

# %%
import time

# %%
dir(time)
# Out:
# ['_STRUCT_TM_ITEMS',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'altzone',
#  'asctime',
#  'clock',
#  'ctime',
#  'daylight',
#  'get_clock_info',
#  'gmtime',
#  'localtime',
#  'mktime',
#  'monotonic',
#  'monotonic_ns',
#  'perf_counter',
#  'perf_counter_ns',
#  'process_time',
#  'process_time_ns',
#  'sleep',
#  'strftime',
#  'strptime',
#  'struct_time',
#  'time',
#  'time_ns',
#  'timezone',
#  'tzname',
#  'tzset']

# %%
help(time.sleep)
# Out:
# Help on built-in function sleep in module time:
#
# sleep(...)
#     sleep(seconds)
#
#     Delay execution for a given number of seconds.  The argument may be
#     a floating point number for subsecond precision.

# %%
#sleeps execution of script for 3 seconds
time.sleep(3)

# %%
import time

while True:
    with open("folder/vegetables.txt") as file:
        print(file.read())
        time.sleep(10)
# Out:
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# tomato
# Cucumber
# Onion
# Garlic
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-3ce9c4a41c6f> in <module>
#       4     with open("folder/vegetables.txt") as file:
#       5         print(file.read())
# ----> 6         time.sleep(10)
#
# KeyboardInterrupt:

# %%
import os

# %%
import sys

# %%
sys.prefix
# Out:
# '/opt/anaconda3'

# %%
os.path.exists("folder/vegetables.txt")
# Out:
# True

# %%
#Check if file exists
import time

while True:
    if os.path.exists("folder/poop.txt"):
        with open("folder/poop.txt") as file:
            print(file.read())
    else:
        print("File does not exist.")
    time.sleep(5)
# Out:
# File does not exist.
# File does not exist.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e0e83d9d2912> in <module>
#       8     else:
#       9         print("File does not exist.")
# ---> 10     time.sleep(5)
#
# KeyboardInterrupt:
