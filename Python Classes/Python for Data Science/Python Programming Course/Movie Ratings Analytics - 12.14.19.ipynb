# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/jonzimmerman/Desktop/pythonpractice/Winter Class/Python Programming Course'

# %%
movies=pd.read_csv("Movie-Ratings.csv")

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
len(movies.columns)
# Out:
# 6

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['Film','Genre','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null object
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
#Don't want to treat Year as a numeric variable

# %%
movies.Film=movies.Film.astype('category')

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
#category is the Python-equivalent of factors in R

# %%
movies.Genre=movies.Genre.astype('category')
movies.Year=movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
#Year column no longer shows up in this output
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %% [markdown]
# ---

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Joint Plot

# %%
sns.set()
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating')

# %%
#kind='hex' option groups clusters 
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='hex')
#associated with distribution spikes

# %%
#Chart 1

# %% [markdown]
# ---

# %%
#Histograms

# %%
m1=sns.distplot(movies.AudienceRating,bins=15)

# %%
m1=sns.distplot(movies.CriticRating,bins=15)

# %%
#Let's look at this distribution without Seaborn, JUST PYPLOT

# %%
#Chart 2
sns.set_style("white")
n1=plt.hist(movies.AudienceRating,bins=15)

# %%
#Chart 3
sns.set_style("darkgrid")
n1=plt.hist(movies.CriticRating,bins=15)

# %% [markdown]
# ---

# %%
#Stacked Histograms

# %%
movies[movies.Genre=="Drama"].BudgetMillions
#plt.hist(movies.BudgetMillions)
#plt.show()
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillions, Length: 101, dtype: int64

# %%
plt.hist(movies[movies.Genre=="Action"].BudgetMillions,bins=25)
plt.hist(movies[movies.Genre=="Thriller"].BudgetMillions,bins=25)
plt.hist(movies[movies.Genre=="Drama"].BudgetMillions,bins=25)

plt.show()
#we want the graphs stacked

# %%
#make this a list
#[movies[movies.Genre=="Action"].BudgetMillions,movies[movies.Genre=="Drama"].BudgetMillions]
plt.hist([movies[movies.Genre=="Action"].BudgetMillions,movies[movies.Genre=="Drama"].BudgetMillions]
,bins=15)
#we get a side by side chart
# Out:
# ([array([ 9., 39., 24., 13., 16.,  9.,  8., 14.,  5.,  4.,  8.,  2.,  2.,
#           0.,  1.]),
#   array([39., 41., 11.,  6.,  2.,  1.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,
#           0.,  0.])],
#  array([  0.,  20.,  40.,  60.,  80., 100., 120., 140., 160., 180., 200.,
#         220., 240., 260., 280., 300.]),
#  <a list of 2 Lists of Patches objects>)

# %%
plt.hist([movies[movies.Genre=="Action"].BudgetMillions,
          movies[movies.Genre=="Drama"].BudgetMillions]
,bins=15,stacked=True)
plt.show()

# %%
#we would have to manually input every genre like this if we continued
#instead - let's just create a loop

# %%
movies.Genre.unique()
# Out:
# [Comedy, Adventure, Action, Horror, Drama, Romance, Thriller]
# Categories (7, object): [Comedy, Adventure, Action, Horror, Drama, Romance, Thriller]

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1=list()
mylabels=list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].BudgetMillions)
    mylabels.append(gen)
    
h=plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %%
#Chart #4

# %% [markdown]
# ---

# %%
#KDE Plot - Kernal Density Plot

# %%
vis1=sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',
                fit_reg=False,
                hue='Genre',
                size=6, aspect=1)

# %%
#Run these together to get smooth, crisp picture

k1=sns.kdeplot(movies.CriticRating,movies.AudienceRating,
               shade=True,shade_lowest=False,cmap='Reds')

k1b=sns.kdeplot(movies.CriticRating,movies.AudienceRating,cmap='Reds')

# %% [markdown]
# ---

# %%
#Working with Subplots()

# %%
sns.set_style("darkgrid")
k1=sns.kdeplot(movies.BudgetMillions,movies.AudienceRating)
#audience rating is closer to a normal distribution

# %%
k1=sns.kdeplot(movies.BudgetMillions,movies.CriticRating)
#critic rating is closer to a uniform distribution

# %%
#1 row, 2 columns
f,ax=plt.subplots(1,2)

# %%
f,ax=plt.subplots(3,2)

# %%
f,axes=plt.subplots(1,2,figsize=(12,6),sharex=True,sharey=True)
k1=sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,ax=axes[0])
k2=sns.kdeplot(movies.BudgetMillions,movies.CriticRating,ax=axes[1])
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
#If you specify (2,2) - you need to correct the axes references too
f,axes=plt.subplots(2,2,figsize=(12,6))
k1=sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,ax=axes[0,0])
k2=sns.kdeplot(movies.BudgetMillions,movies.CriticRating,ax=axes[1,1])

# %% [markdown]
# ---

# %%
#ViolinPlots

# %%
#w=sns.boxplot(data=movies,x='Genre',y='CriticRating')
w=sns.boxplot(data=movies[movies.Genre=="Drama"],x='Year',y='CriticRating')

# %%
z=sns.violinplot(data=movies[movies.Genre=="Drama"],x='Year',y='CriticRating')

# %%
#Violin plot gives you a little more information about 
#the distribution of data

# %% [markdown]
# ---

# %%
#Creating Facet Grids

# %%
#g=sns.FacetGrid(movies,row='Genre',hue='Genre')
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')

# %%
#click in box to compact the space

# %%
#g.map --> pass in function and then arguments separately here
#these wont work separately, must be run together
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g=g.map(plt.scatter,'CriticRating','AudienceRating')

#g.map uses the construct of the scatterplot function
#plt.scatter(movies.CriticRating,movies.AudienceRating)

# %%
#Can populate with any type of chart Ex: histogram

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g=g.map(plt.hist,'BudgetMillions')

# %%
#Back to scatterplot
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
kws=dict(s=50,linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'CriticRating','AudienceRating',**kws)
#make the dots bigger and outlined

# %% [markdown]
# ---

# %%
#Let's add a diagonal to the graph

# %%
#Controlling axes and adding diagonals
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
kws=dict(s=50,linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'CriticRating','AudienceRating',**kws)

g.set(xlim=(0,100),ylim=(0,100))

for ax in g.axes.flat:
    ax.plot((20,60),(20,60))
#see the graphs below - doesn't quite give us what we want

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
kws=dict(s=50,linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'CriticRating','AudienceRating',**kws)

g.set(xlim=(0,100),ylim=(0,100))

for ax in g.axes.flat:
    ax.plot((0,100),(0,100),c="gray",ls="--")
g.add_legend()
    
#When data is above diagonal --> means audience rating was 
#better than critic rating

# %%
#Chart #5

# %% [markdown]
# ---

# %%
#Building Dashboards in Python

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#F=figure, axes=axes
sns.set_style("darkgrid")
f,axes=plt.subplots(2,2,figsize=(15,15))

k1=sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,ax=axes[0,0])
k2=sns.kdeplot(movies.BudgetMillions,movies.CriticRating,ax=axes[0,1])

z=sns.violinplot(data=movies[movies.Genre=="Drama"],x='Year',y='CriticRating',ax=axes[1,0])

#Rememeber: these two need to be run together!
k4=sns.kdeplot(movies.CriticRating,movies.AudienceRating,
              shade=True,shade_lowest=False,cmap='Reds',ax=axes[1,1])
k4b=sns.kdeplot(movies.CriticRating,movies.AudienceRating,cmap='Reds'
               ,ax=axes[1,1])

#What if we wanted to include a non-Seaborn plot in the dashboard?
#-----------------------------------------------------------------#

#WILL NOT WORK IF YOU INCLUDE A NON-SEABORN PLOT LIKE THIS    
#n1=plt.hist(movies.CriticRating,bins=15,ax=axes[1,1])

#IF YOU INCLUDE PYPLOT PLOT - YOU NEED TO USE THIS SYNTAX INSTEAD
#axes[1,1].hist(movies.CriticRating,bins=15)

#axes[#,#] --> this is a pyplot object - only works for plt plots, if you
#try this method of plotting with seaborn object - will not work!

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
#Styling Dashboards

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#F=figure, axes=axes
sns.set_style("dark",{"axes.facecolor":"black"}) #OTHER OPTIONS --> white, whitegrid, 
                          #dark, darkgrid, and ticks
f,axes=plt.subplots(2,2,figsize=(15,15))


#Color map is currently inferno, if you do inferno_r --> reverses color scheme
#Plot [0,0]
k1=sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,
               ax=axes[0,0],shade=True,shade_lowest=True,cmap='inferno')
#Include this second line for the outlines
k1b=sns.kdeplot(movies.BudgetMillions,movies.AudienceRating,
               ax=axes[0,0],cmap='cool')
#Plot [0,1]
k2=sns.kdeplot(movies.BudgetMillions,movies.CriticRating,
               ax=axes[0,1],shade=True,shade_lowest=True,cmap='inferno')
k2b=sns.kdeplot(movies.BudgetMillions,movies.CriticRating,
               ax=axes[0,1],cmap='cool')
#Plot [1,0]
z=sns.violinplot(data=movies,
                 x='Year',y='BudgetMillions',ax=axes[1,0],
                palette='YlOrRd')
#Plot [1,1]

#we originally had a color that faded to white on the outside edges,
# didnt look good with the black background, so we chose the blues_r or
#reverse blue so it starts as white in the middle and fades to blue on
#the edges
k4=sns.kdeplot(movies.CriticRating,movies.AudienceRating,
              shade=True,shade_lowest=False,cmap='Blues_r',ax=axes[1,1])
k4b=sns.kdeplot(movies.CriticRating,movies.AudienceRating,cmap='gist_gray_r'
               ,ax=axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
plt.show()

# %% [markdown]
# ---

# %%
#Thematic Edits


list1=list()
mylabels=list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].BudgetMillions)
    mylabels.append(gen)

#sns object set_style can affect non-seaborn objects
sns.set_style("whitegrid")

#Create subplot with one plot - allows us to edit size and other things
fig,ax=plt.subplots()
fig.set_size_inches(8.7,5.27) #size of paper
h=plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabels)

plt.title("Movie Budget Distribution by Genre",fontsize=20,
         color='DarkBlue')
plt.ylabel("Number of Movies",fontsize=20,color="Red")
plt.xlabel("Budget",fontsize=20,color="Green")
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(frameon=True,fancybox=True,shadow=True,framealpha=1,prop={'size':15})
plt.show()
