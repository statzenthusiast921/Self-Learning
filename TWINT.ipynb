# %%
from google.colab import drive
drive.mount('gdrive')
# Out:
# Mounted at gdrive

# %%
# %cd /content/gdrive/My Drive/TwintUdemy/
# Out:
# /content/gdrive/My Drive/TwintUdemy

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/TwintUdemy

# %%
# !ls

# %%
# !pip install nest-asyncio

# %%
# !git clone --depth=1 https://github.com/twintproject/twint.git
# !cd twint
#!pip3 install . -r requirements.txt
# Out:
# fatal: destination path 'twint' already exists and is not an empty directory.

# %%
# !pip3 install . -r requirements.txt
# Out:
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.

# %%
# !ls
# Out:
# twint

# %%
# !pip3 install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# ...
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to /tmp/pip-install-26zjti21/twint
#   Running command git clone -q https://github.com/twintproject/twint.git /tmp/pip-install-26zjti21/twint
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
# ...
#   Created wheel for twint: filename=twint-2.1.21-cp37-none-any.whl size=38872 sha256=3f8ddca0209831bd8b9b77202eb37ddb241936b8b3b64328354f417455c2ddde
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pdh7t_rv/wheels/4f/3b/75/62d04b3b446658ba85401e8868d3cd1d4bc22f17ad755460a6
# Successfully built twint
# ...
#   Found existing installation: twint 2.1.21
#     Uninstalling twint-2.1.21:
#       Successfully uninstalled twint-2.1.21
#   WARNING: The script twint is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
# !mv src/twint .
# !rm -r src
# Out:
# mv: cannot stat 'src/twint': No such file or directory
# rm: cannot remove 'src': No such file or directory

# %%
# %load_ext autoreload

# %%
# %autoreload 2
import sys
sys.path.append('twint/')

# %%
# !pip install "googletransx==2.4.2"
# !pip install twint
import twint
import pandas as pd
import nest_asyncio
nest_asyncio.apply()

# %%
# !pip3 uninstall twint
# Out:
# Uninstalling twint-2.1.21:
#   Would remove:
#     /root/.local/bin/twint
#     /root/.local/lib/python3.7/site-packages/twint-2.1.21.dist-info/*
#     /root/.local/lib/python3.7/site-packages/twint/*
# Proceed (y/n)? y
#   Successfully uninstalled twint-2.1.21

# %%
# !pip3 install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# ...
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to /tmp/pip-install-zu8wsu9k/twint
#   Running command git clone -q https://github.com/twintproject/twint.git /tmp/pip-install-zu8wsu9k/twint
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
# ...
#   Created wheel for twint: filename=twint-2.1.21-cp37-none-any.whl size=38872 sha256=5502aa46d00e6386f9d8089b5cc2cbfccc2bde6ec73438da8d1938b9d0cd259d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wv7q6080/wheels/4f/3b/75/62d04b3b446658ba85401e8868d3cd1d4bc22f17ad755460a6
# Successfully built twint
# ...
#   WARNING: The script twint is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
c = twint.Config()
c.Pandas = True
c.Store_csv = True
c.Search="#COVID19"
c.Limit = 150
c.Lang = "en"
c.Since = "2000-01-01"
c.Until = "2021-04-30"

# %%
twint.run.Search(c)
# Out:
# 1387919571168997379 2021-04-29 23:59:46 +0000 <SD_ICTP> Please follow SOPs, wear Mask, use Senitizer, and avoid crowded places. #humsabkaislamabad #COVID19  @ICT_Police
# 1387919557738729474 2021-04-29 23:59:43 +0000 <sayk_art> #COVID19 #COVID19India #coronavirus #Corona #COVID #CoronavirusPandemic #Covid_19 #IndiaFightsCOVID19 #pandemic #SystemहीSarkar #System #SYSTEM_IS_ANI #ResignModi
# 1387919544501428224 2021-04-29 23:59:40 +0000 <ASRAR_1968> #COVID19 #ModiGovtSeNaHoPayega #ModiResign #ModiFailsIndia
# 1387919539216818182 2021-04-29 23:59:39 +0000 <GavilanCollege> Californianos pueden recibir la vacuna gratis sin importar cuál sea su estatus migratorio!  No se te debe preguntar sobre tu estatus migratorio o de ciudadanía cuando recibes la vacuna #COVID19.  Ve a  https://t.co/H3vmeZ5K3H para obtener más información.  #TerminemosConLaPandemia  https://t.co/d0VUMAr0GY
# ...

# %%
twint.storage.panda.Tweets_df.head()
# Out:
#                     id      conversation_id  ...  trans_src trans_dest
# 0  1387919571168997379  1387919571168997379  ...
# 1  1387919557738729474  1387919557738729474  ...
# 2  1387919544501428224  1387919544501428224  ...
# 3  1387919539216818182  1387919539216818182  ...
# 4  1387919534313574406  1387919534313574406  ...
#
# [5 rows x 38 columns]

# %%
twint.storage.panda.Tweets_df.count()[1]
# Out:
# 200

# %%
twint.storage.panda.Tweets_df['tweet'][0]
# Out:
# 'Please follow SOPs, wear Mask, use Senitizer, and avoid crowded places. #humsabkaislamabad #COVID19  @ICT_Police'

# %%
twint.storage.panda.Tweets_df.to_csv('COVID19_sample_Twitter_scraping.csv')
# !cp 'COVID19_sample_Twitter_scraping.csv' "/content/gdrive/My Drive/Colab Notebooks/TwintUdemy"

# %%
#SEARCH BY USERNAME
c = twint.Config()
c.Pandas = True
c.Store_csv = True
c.Username ="elonmusk"
c.Limit = 500
c.Lang = "en"
c.Since = "2020-01-01"
c.Until = "2021-05-01"

# %%
twint.run.Search(c)
# Out:
# 1387901003664699392 2021-04-29 22:45:59 +0000 <elonmusk> A major part of real-world AI has to be solved to make unsupervised, generalized full self-driving work, as the entire road system is designed for biological neural nets with optical imagers
# 1387897099983990793 2021-04-29 22:30:29 +0000 <elonmusk> @WholeMarsBlog Exactly!
# 1387894284041527297 2021-04-29 22:19:17 +0000 <elonmusk> @teslaownersSV Was using this in my car last night
# 1387893690354515970 2021-04-29 22:16:56 +0000 <elonmusk> @teslaownersSV FSD display V9.0 will show actual probability distribution of objects – true mind’s eye of the neural net. This is so cool!
# 1387892910960615428 2021-04-29 22:13:50 +0000 <elonmusk> @WhatsupFranks @danheld I swear Canada FSD beta will be as soon as humanly possible!
# ...

# %%
twint.storage.panda.Tweets_df['tweet'].count()
# Out:
# 500

# %%
print(twint.storage.panda.Tweets_df['tweet'][100])
print(twint.storage.panda.Tweets_df['tweet'][10])
print(twint.storage.panda.Tweets_df['tweet'][499])
# Out:
# 🚀🖤💫 NASA Rules!! 💫🖤🚀
# @teslaownersSV @TeslaNY @Tesla Gating factor is achieving &amp; proving higher safety with pure vision than with vision+radar. We are almost there.  FSD Beta V9.0 will blow your mind.
# @jeff_foust Rockets are ridiculously hard (sigh)

# %%
#SEARCH BY GEOTAGS
c = twint.Config()
c.Pandas = True
c.Store_csv = True
c.Geo="51.5, -0.127, 15km"
c.Search = "bitcoin"
c.Limit = 5000
#c.Lang = "en"
c.Since = "2015-06-01"
c.Until = "2015-07-01"

# %%
twint.run.Search(c)
# Out:
# 615797113566265344 2015-06-30 08:20:47 +0000 <FriendlyScore> Interesting new #Bitcoin #P2PLending platform #Yikes Lend to friends of your facebook friends that have their vouch  http://t.co/F059xBDffT
# 615760349548011520 2015-06-30 05:54:42 +0000 <still_les> Bitcoin accused of wasting shocking amount of electricity  http://t.co/0IAT5kWy4B have you ever hesrd such crap
# 615624260820803585 2015-06-29 20:53:56 +0000 <sytaylor> @dgwbirch the bitcoin blockchain allows your to choose a known miner. It's like a VPN on an open network.
# 615492611088977920 2015-06-29 12:10:48 +0000 <wearebankable> London is becoming a global hub for #innovation using #digitalcurrency #Bitcoin in aspiration to move #money faster.   http://t.co/a2kkUUry99
# 614545275701608448 2015-06-26 21:26:26 +0000 <iamwilliamking> @MrChrisEllis bitcoin in @standardnews today  http://t.co/sCt8mIFkQu
# ...

# %%
twint.storage.panda.Tweets_df['tweet'].count()
# Out:
# 46

# %%
twint.storage.panda.Tweets_df.head()
# Out:
#                    id     conversation_id  ...  trans_src trans_dest
# 0  615797113566265344  615797113566265344  ...
# 1  615760349548011520  615760349548011520  ...
# 2  615624260820803585  615623800596598784  ...
# 3  615492611088977920  615492611088977920  ...
# 4  614545275701608448  614543555403624448  ...
#
# [5 rows x 38 columns]

# %%
twint.storage.panda.Tweets_df['tweet'][0]
# Out:
# 'Interesting new #Bitcoin #P2PLending platform #Yikes Lend to friends of your facebook friends that have their vouch  http://t.co/F059xBDffT'
